# %% [markdown]
# # Python bevezetés

# %% [markdown]
# Ebben a notebook-ban a Python alapjait vesszük át.
# Alapvetően a notebook két részben mutatja be a pythont. Egyrészt egy technikaibb áttekintést nyújt, másrészt az adatelemzéshez szükséges könyvtárak közül a "legnépszerűbbeket" mutatja be.
#
# **1. Technikaibb áttekintés:**
# * anaconda környezet felállítása
# * python csomagok telepítése
# * ismerkedés a jupyter notebook-al
# <br>
# <br>
# python_bevezetés_I notebook
#
# **2. Adatelemzősebb áttekintés:**
# * Adattípusok
# * csomagok importálása
# * pandas
# * adatok beolvasása
# * adatfeltárás
# * adatvizualizáció
# <br>
# <br>
# python_bevezetés_II notebook

# %% [markdown]
# ## --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2. Adatelemzősebb áttekintés

# %% [markdown]
# ## 2.1 Pandas
# A Pandas a legalapvetőbb csomag az adatelemzési feladatoknál. Ez a csomag teszi lehetővé, hogy az adatokat kezelni tudjuk (beolvasás, tárolás, adatelőkészítés, műveletek, szűrés, indexelés, stb.)
# <br>
# A neve a "panel datas"-ra utal ~ R dataframe.
# <br>
# **A későbbiekben fontos lesz, hiszen a dokumentumgyűjteményünk, korpuszunk is Pandas DataFrame objektumban lesz tárolva**

# %% [markdown]
# **Modul importálása**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Series objektumok létrehozása**
# <br>
# A Series objektumot önmagában ritkán használjuk, egy DataFrame oszlopaként szoktunk dolgozni vele. Létrehozhatjuk egy meglevő python listából, szótárból vagy más (pl. NumPy) objektumokból is.

# %%
cities = pd.Series(['Budapest', 'NY', 'Tokyo', 'Moscow', 'Bucharest'], name = 'cities')
print("Cities series hossza: {}".format(len(cities)))
cities
# Out:
# Cities series hossza: 5
# 0     Budapest
# 1           NY
# 2        Tokyo
# 3       Moscow
# 4    Bucharest
# Name: cities, dtype: object

# %%
pop = pd.Series(np.random.randint(20, size=5), name = 'population')
print("Pop series hossza: {}".format(len(pop)))
pop
# Out:
# Pop series hossza: 5
# 0    19
# 1    12
# 2     6
# 3    15
# 4     0
# Name: population, dtype: int32

# %% [markdown]
# **DataFrame objektum létrehozása pandas Series objektumokból**
# <br>
# A pandas DataFrame egy N dimenziós pandas Series tömb, ahol minden Series-nek ugyanaz a sorindexe.

# %%
df1 = pd.concat([cities, pop], axis = 1)
df1
# Out:
#       cities  population
# 0   Budapest          19
# 1         NY          12
# 2      Tokyo           6
# 3     Moscow          15
# 4  Bucharest           0

# %% [markdown]
# **Ugyanezt a DataFrame-et létrehozhatjuk listákból és/vagy szótárakból**

# %%
df2 = pd.DataFrame({'cities': ['Budapest', 'NY', 'Tokyo', 'Moscow', 'Bucharest'], 
                    'population': list(np.random.randint(20, size=5))})
df2
# Out:
#       cities  population
# 0   Budapest           2
# 1         NY           2
# 2      Tokyo          11
# 3     Moscow          19
# 4  Bucharest          19

# %% [markdown]
# ### 2.1.1 Adatfájlok beolvasása
# Egy adatelemzési feladatnál az adatokat elérhetjük valamilyen adatbázishoz való kapcsolaton keresztül vagy excel,csv fájlok beolvasásával.

# %% [markdown]
# **-CSV fájlok beolvasása**
# <br>
# A pandas read_csv() metódusát kell használni, amely legfontosabb és legtöbbet haszbált paraméterei:
# <br>
# * **file_path**: fájl elérési útvonala és neve,
# * **sep**: csv fájlban használt elválasztó,
# * **header**: van-e a fájlnak fejléce, TRUE: akkor ezek lesznek az oszlopnevek,
# * **encoding**: fájl karaktereinek kódolása, !Fontos: utf-8
# <br>
# <br>
# Hivatkozás: (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
wine_reviews = pd.read_csv("C:/Users/molna/Downloads/archive/winemag-data-130k-v2.csv", header=0, sep=",", encoding="utf-8")

# %% [markdown]
# **Belenézés az adatokba**

# %%
wine_reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
wine_reviews.tail(2)
# Out:
#         Unnamed: 0 country                                        description  \
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province region_1  \
# 129969                            NaN      90   32.0   Alsace   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace   Alsace
#
#        region_2 taster_name taster_twitter_handle  \
# 129969      NaN  Roger Voss            @vossroger
# 129970      NaN  Roger Voss            @vossroger
#
#                                                     title         variety  \
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit

# %% [markdown]
# ### 2.1.2 Áttekintő műveletek

# %% [markdown]
# A dataframe méretei egyszerűen lekérdezhetőek (sorok és oszlopok):

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %% [markdown]
# Sorok számának lekérése:

# %%
len(wine_reviews)
# Out:
# 129971

# %% [markdown]
# Oszlopok nevének lekérése:

# %%
wine_reviews.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# Rövid áttekintés az oszlopok tulajdonságairól (kitöltöttség, adattípus):

# %%
wine_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# Alapstatisztikák csak numerikus oszlopokról a describe() parancs használatával:

# %%
wine_reviews.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %% [markdown]
# ### 2.1.3 Indexelés, leválogatás

# %% [markdown]
# **DataFrame tetszőleges részének lekérdezése (és módosítása)**
# <br>
# A táblázatunk (DataFrame) egyes celláinak, oszlopainak, sorainak esetleg táblázat meghatározott részeinek a lekérdezése a leggyakrabban használt művelet az adatfeldolgozás során.
# <br>
# <br>
# Ha DataFrame-ek esetében csak bizonyos cellák értékére vagyunk kíváncsiak, vagy csak bizonyos értékeket szeretnénk felülírni, akkor a loc() vagy iloc() függvényeket használhatjuk. Az előbbi használatakor a sor és oszlop címkéket vesszővel elválasztva kell megadni, míg az utóbbinál sorszámokat használhatunk.

# %% [markdown]
# **Oszlopok leválogatása**

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews[['country', 'winery']]
# Out:
#          country                                    winery
# 0          Italy                                   Nicosia
# 1       Portugal                       Quinta dos Avidagos
# 2             US                                 Rainstorm
# 3             US                                St. Julian
# 4             US                              Sweet Cheeks
# ...          ...                                       ...
# 129966   Germany  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967        US                                  Citation
# 129968    France                           Domaine Gresser
# 129969    France                      Domaine Marcel Deiss
# 129970    France                          Domaine Schoffit
#
# [129971 rows x 2 columns]

# %% [markdown]
# **Cella lekérdezése címkék (index és oszlop címkék) alapján:**
# <br>
# .loc[sor, oszlop]

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews[['country', 'winery']]
# Out:
#          country                                    winery
# 0          Italy                                   Nicosia
# 1       Portugal                       Quinta dos Avidagos
# 2             US                                 Rainstorm
# 3             US                                St. Julian
# 4             US                              Sweet Cheeks
# ...          ...                                       ...
# 129966   Germany  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967        US                                  Citation
# 129968    France                           Domaine Gresser
# 129969    France                      Domaine Marcel Deiss
# 129970    France                          Domaine Schoffit
#
# [129971 rows x 2 columns]

# %% [markdown]
# **Cella lekérdezése címkék (index és oszlop címkék) alapján:**
# <br>
# .loc[sor, oszlop]

# %%
wine_reviews.loc[0, 'taster_twitter_handle']
# Out:
# '@kerinokeefe'

# %% [markdown]
# Az iloc() index alapú.
# Az iloc() is cellát vagy cellákat kérdez le, de sorszám és nem index cimke alapján:

# %%
wine_reviews.iloc[0, 10]
# Out:
# '@kerinokeefe'

# %%
wine_reviews.iloc[:, 1]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %% [markdown]
# Első sor oszlopértékeit .loc indexeléssel is lekérhetjük:

# %%
wine_reviews.loc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# winery                                                             Nicosia
# Name: 0, dtype: object

# %% [markdown]
# Komplexebb példa:
# <br>
# Winery datafreme 3 oszlopának első 11 sorának leválogatása

# %%
wine_reviews.loc[0:10, ['country', 'winery', 'price']]
# Out:
#      country               winery  price
# 0      Italy              Nicosia    NaN
# 1   Portugal  Quinta dos Avidagos   15.0
# 2         US            Rainstorm   14.0
# 3         US           St. Julian   13.0
# 4         US         Sweet Cheeks   65.0
# 5      Spain               Tandem   15.0
# 6      Italy      Terre di Giurfo   16.0
# 7     France             Trimbach   24.0
# 8    Germany          Heinz Eifel   12.0
# 9     France   Jean-Baptiste Adam   27.0
# 10        US   Kirkland Signature   19.0

# %% [markdown]
# Komplexebb példa:
# <br>
# Winery datafreme 3 oszlopának első 11 sorának leválogatása

# %%
wine_reviews.loc[0:10, ['country', 'winery', 'price']]
# Out:
#      country               winery  price
# 0      Italy              Nicosia    NaN
# 1   Portugal  Quinta dos Avidagos   15.0
# 2         US            Rainstorm   14.0
# 3         US           St. Julian   13.0
# 4         US         Sweet Cheeks   65.0
# 5      Spain               Tandem   15.0
# 6      Italy      Terre di Giurfo   16.0
# 7     France             Trimbach   24.0
# 8    Germany          Heinz Eifel   12.0
# 9     France   Jean-Baptiste Adam   27.0
# 10        US   Kirkland Signature   19.0

# %%
wine_reviews[['country', 'winery', 'price']].head(11)
# Out:
#      country               winery  price
# 0      Italy              Nicosia    NaN
# 1   Portugal  Quinta dos Avidagos   15.0
# 2         US            Rainstorm   14.0
# 3         US           St. Julian   13.0
# 4         US         Sweet Cheeks   65.0
# 5      Spain               Tandem   15.0
# 6      Italy      Terre di Giurfo   16.0
# 7     France             Trimbach   24.0
# 8    Germany          Heinz Eifel   12.0
# 9     France   Jean-Baptiste Adam   27.0
# 10        US   Kirkland Signature   19.0

# %% [markdown]
# ### Feltételes leválogatás
# Amikor a teljes adathalmazból csak azok a sorok érdekelnek, amelyek bizonyos feltételeknek megfelelnek.
# Ekkor logikai feltételeket is alkalmazhatunk, melyekkel a feltételeket teljesítő sorokat kapjuk vissza.

# %% [markdown]
# Péda:
# <br>
# Azon borok leválogatása, amelyek származási helye Olaszország és nagyobb pontszámot értek el, mint 90.

# %%
wine_reviews[(wine_reviews.country == 'Italy') & (wine_reviews.points > 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 120            120   Italy  Slightly backward, particularly given the vint...
# 130            130   Italy  At the first it was quite muted and subdued, b...
# 133            133   Italy  Einaudi's wines have been improving lately, an...
# 135            135   Italy  The color is just beginning to show signs of b...
# 158            158   Italy  Baked plum, Asian spice, vanilla and menthol a...
# ...            ...     ...                                                ...
# 129675      129675   Italy  Aromas of underbrush, leather, mature berry, g...
# 129681      129681   Italy  Ripe black-skinned berry, violet, leather and ...
# 129892      129892   Italy  Classic Sangiovese aromas of red berry, culina...
# 129893      129893   Italy  Aromas of passion fruit, hay and a vegetal not...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
#
#                     designation  points  price  province  \
# 120         Bricco Rocche Prapó      92   70.0  Piedmont
# 130       Bricco Rocche Brunate      91   70.0  Piedmont
# 133                         NaN      91   68.0  Piedmont
# 135                      Sorano      91   60.0  Piedmont
# 158     Bellezza Gran Selezione      91   38.0   Tuscany
# ...                         ...     ...    ...       ...
# 129675               Montersino      93   50.0  Piedmont
# 129681               Tre Stelle      93   60.0  Piedmont
# 129892                      NaN      91   72.0   Tuscany
# 129893             Corte Menini      91    NaN    Veneto
# 129929                      NaN      91   38.0    Veneto
#
#                               region_1 region_2    taster_name  \
# 120                             Barolo      NaN            NaN
# 130                             Barolo      NaN            NaN
# 133                             Barolo      NaN            NaN
# 135                             Barolo      NaN            NaN
# 158                   Chianti Classico      NaN  Kerin O’Keefe
# ...                                ...      ...            ...
# 129675                      Barbaresco      NaN  Kerin O’Keefe
# 129681                      Barbaresco      NaN  Kerin O’Keefe
# 129892          Brunello di Montalcino      NaN  Kerin O’Keefe
# 129893                  Soave Classico      NaN  Kerin O’Keefe
# 129929  Prosecco Superiore di Cartizze      NaN            NaN
#
#        taster_twitter_handle  \
# 120                      NaN
# 130                      NaN
# 133                      NaN
# 135                      NaN
# 158             @kerinokeefe
# ...                      ...
# 129675          @kerinokeefe
# 129681          @kerinokeefe
# 129892          @kerinokeefe
# 129893          @kerinokeefe
# 129929                   NaN
#
#                                                     title     variety  \
# 120            Ceretto 2003 Bricco Rocche Prapó  (Barolo)    Nebbiolo
# 130          Ceretto 2003 Bricco Rocche Brunate  (Barolo)    Nebbiolo
# 133                     Poderi Luigi Einaudi 2003  Barolo    Nebbiolo
# 135                 Giacomo Ascheri 2001 Sorano  (Barolo)    Nebbiolo
# 158     Castello di Gabbiano 2012 Bellezza Gran Selezi...  Sangiovese
# ...                                                   ...         ...
# 129675         Albino Rocca 2013 Montersino  (Barbaresco)    Nebbiolo
# 129681   Cascina delle Rose 2013 Tre Stelle  (Barbaresco)    Nebbiolo
# 129892           La Mannella 2012  Brunello di Montalcino  Sangiovese
# 129893   Le Mandolare 2015 Corte Menini  (Soave Classico)   Garganega
# 129929  Col Vetoraz Spumanti NV  Prosecco Superiore di...    Prosecco
#
#                       winery
# 120                  Ceretto
# 130                  Ceretto
# 133     Poderi Luigi Einaudi
# 135          Giacomo Ascheri
# 158     Castello di Gabbiano
# ...                      ...
# 129675          Albino Rocca
# 129681    Cascina delle Rose
# 129892           La Mannella
# 129893          Le Mandolare
# 129929  Col Vetoraz Spumanti
#
# [4265 rows x 14 columns]

# %% [markdown]
# Péda:
# <br>
# Azon borok leválogatása, amelyek Olaszországból vagy Franciaországból valók és a legalacsonyabb a pontszámuk.
# <br>
# !Fontos: a logikai zárójelezésre mindig nagyon oda kell figyelni!

# %%
wine_reviews[((wine_reviews.country == 'Italy') | 
              (wine_reviews.country == 'France')) & 
             (wine_reviews.points == wine_reviews.points.min())]
# Out:
#         Unnamed: 0 country                                        description  \
# 4556          4556   Italy  There's a thorny, almost raw quality of fruit ...
# 11085        11085  France  A white this age should be fresh and crisp; th...
# 11086        11086  France  Picture grandma standing over a pot of stewed ...
# 16846        16846   Italy  Thin brambly aromas and wet rubber don't bode ...
# 19122        19122  France  Bold and very clumsy. There are leathery eleme...
# 19123        19123  France  Heavy and waxy, with overdone varietal aromas ...
# 30107        30107   Italy  This diluted wine opens with aromas suggesting...
# 36526        36526  France  This vivid pink-colored wine tastes of candy w...
# 79714        79714  France  Blurred edges characterize the non-distinct ap...
# 90927        90927  France  Lean and rather dry, this has old wood and lea...
# 90932        90932  France  This very ripe wine tastes of supermature grap...
# 91838        91838  France  A very neutral wine, this has some earthy spic...
# 91839        91839  France  Flavors of apple are spoiled by notes of mud a...
# 91840        91840  France  The nose is subdued while the palate shows som...
# 92450        92450  France  Curiously dusty wine, tasting of under-ripe cr...
# 107776      107776   Italy  Made from partially fermented grape must, this...
# 113921      113921  France  Fat, simple wine that offers ripe apples, but ...
# 113926      113926  France  A serviceable fizz but with off-beat aromas of...
# 123541      123541   Italy  This Valpolicella blend opens with an aged, br...
# 123543      123543  France  Earthy and rustic, this Pinot Noir is lightwei...
#
#                      designation  points  price              province  \
# 4556                   Rondineto      80   12.0         Central Italy
# 11085                        NaN      80    8.0      Southwest France
# 11086                        NaN      80   11.0  Languedoc-Roussillon
# 16846               Le Mandorlae      80   11.0               Tuscany
# 19122                        NaN      80    8.0  Languedoc-Roussillon
# 19123   Vin de Pays de l'Ardeche      80   10.0          France Other
# 30107                  Rubentino      80   10.0         Central Italy
# 36526             Gamay-Grolleau      80   11.0          Loire Valley
# 79714                 Hahnenberg      80   25.0                Alsace
# 90927                     Hyppos      80   25.0              Bordeaux
# 90932                        NaN      80   20.0              Bordeaux
# 91838                        NaN      80   18.0                Alsace
# 91839           Special Delivery      80   15.0                Alsace
# 91840                  Tradition      80   17.0                Alsace
# 92450                        NaN      80   23.0          Loire Valley
# 107776             Rosso e Dolce      80   11.0           Italy Other
# 113921      Blanc de Blancs Brut      80   13.0          France Other
# 113926          Giersberger Brut      80   14.0                Alsace
# 123541              Corte Antica      80    NaN                Veneto
# 123543                       NaN      80   20.0                Alsace
#
#                                region_1 region_2        taster_name  \
# 4556                     Colli Aprutini      NaN                NaN
# 11085                          Bergerac      NaN     Joe Czerwinski
# 11086                             Fitou      NaN     Joe Czerwinski
# 16846             Morellino di Scansano      NaN  Michael Schachner
# 19122                  Vin de Pays d'Oc      NaN  Michael Schachner
# 19123                            France      NaN  Michael Schachner
# 30107           Montepulciano d'Abruzzo      NaN      Kerin O’Keefe
# 36526                      Rosé d'Anjou      NaN         Roger Voss
# 79714                            Alsace      NaN   Anne Krebiehl MW
# 90927                Bordeaux Supérieur      NaN         Roger Voss
# 90932                Bordeaux Supérieur      NaN         Roger Voss
# 91838                            Alsace      NaN   Anne Krebiehl MW
# 91839                            Alsace      NaN   Anne Krebiehl MW
# 91840                            Alsace      NaN   Anne Krebiehl MW
# 92450                          Sancerre      NaN         Roger Voss
# 107776                            Italy      NaN                NaN
# 113921                     Vin Mousseux      NaN         Roger Voss
# 113926                 Crémant d'Alsace      NaN                NaN
# 123541  Valpolicella Classico Superiore      NaN                NaN
# 123543                           Alsace      NaN         Roger Voss
#
#        taster_twitter_handle  \
# 4556                     NaN
# 11085                 @JoeCz
# 11086                 @JoeCz
# 16846            @wineschach
# 19122            @wineschach
# 19123            @wineschach
# 30107           @kerinokeefe
# 36526             @vossroger
# 79714            @AnneInVino
# 90927             @vossroger
# 90932             @vossroger
# 91838            @AnneInVino
# 91839            @AnneInVino
# 91840            @AnneInVino
# 92450             @vossroger
# 107776                   NaN
# 113921            @vossroger
# 113926                   NaN
# 123541                   NaN
# 123543            @vossroger
#
#                                                     title  \
# 4556    Fattoria Giuseppe Savini 2011 Rondineto Merlot...
# 11085         Seigneurs de Bergerac 1999 White (Bergerac)
# 11086                         Mont Tauch 1998 Red (Fitou)
# 16846   Baroncini 1998 Le Mandorlae  (Morellino di Sca...
# 19122   Château de Pennautier 2001 Cabernet Sauvignon ...
# 19123   Georges Duboeuf 2001 Vin de Pays de l'Ardeche ...
# 30107   Tenimenti Montagnana 2014 Rubentino  (Montepul...
# 36526        Bougrier 2015 Gamay-Grolleau  (Rosé d'Anjou)
# 79714   Domaine Bernhard & Reibel 2014 Hahnenberg Pino...
# 90927   Château Majoureau 2009 Hyppos  (Bordeaux Supér...
# 90932          Château Timberlay 2009  Bordeaux Supérieur
# 91838   Domaine de la Tour Blanche 2014 Pinot Blanc (A...
# 91839   Frédéric Mallo 2014 Special Delivery Pinot Bla...
# 91840      Kuentz-Bas 2014 Tradition Pinot Blanc (Alsace)
# 92450                        Michel Picard 2007  Sancerre
# 107776      Stella Mia NV Rosso e Dolce Brachetto (Italy)
# 113921  Silver Cap NV Blanc de Blancs Brut Sparkling (...
# 113926  Cave de Ribeauvillé NV Giersberger Brut Sparkl...
# 123541  Cantine Benedetti 2008 Corte Antica  (Valpolic...
# 123543  La Cave des Vignerons de Pfaffenheim 2009 Pino...
#
#                               variety                                winery
# 4556                           Merlot              Fattoria Giuseppe Savini
# 11085                     White Blend                 Seigneurs de Bergerac
# 11086                       Red Blend                            Mont Tauch
# 16846                      Sangiovese                             Baroncini
# 19122              Cabernet Sauvignon                 Château de Pennautier
# 19123                        Viognier                       Georges Duboeuf
# 30107                   Montepulciano                  Tenimenti Montagnana
# 36526                            Rosé                              Bougrier
# 79714                      Pinot Gris             Domaine Bernhard & Reibel
# 90927        Bordeaux-style Red Blend                     Château Majoureau
# 90932        Bordeaux-style Red Blend                     Château Timberlay
# 91838                     Pinot Blanc            Domaine de la Tour Blanche
# 91839                     Pinot Blanc                        Frédéric Mallo
# 91840                     Pinot Blanc                            Kuentz-Bas
# 92450                 Sauvignon Blanc                         Michel Picard
# 107776                      Brachetto                            Stella Mia
# 113921                Sparkling Blend                            Silver Cap
# 113926                Sparkling Blend                   Cave de Ribeauvillé
# 123541  Corvina, Rondinella, Molinara                     Cantine Benedetti
# 123543                     Pinot Noir  La Cave des Vignerons de Pfaffenheim

# %% [markdown]
# Példa:
# <br>
# Azon sorok leválogatása, ahol vagy olaszországi vagy franciaországi a bor.

# %%
wine_reviews.loc[wine_reviews.country.isin(['Italy', 'France'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# ...            ...     ...                                                ...
# 129964      129964  France  Initially quite muted, this wine slowly develo...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 7                                 NaN      87   24.0             Alsace
# 9                         Les Natures      87   27.0             Alsace
# 11                                NaN      87   30.0             Alsace
# ...                               ...     ...    ...                ...
# 129964   Domaine Saint-Rémy Herrenweg      90    NaN             Alsace
# 129965    Seppi Landmann Vallée Noble      90   28.0             Alsace
# 129968                          Kritt      90   30.0             Alsace
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 6       Vittoria      NaN  Kerin O’Keefe          @kerinokeefe
# 7         Alsace      NaN     Roger Voss            @vossroger
# 9         Alsace      NaN     Roger Voss            @vossroger
# 11        Alsace      NaN     Roger Voss            @vossroger
# ...          ...      ...            ...                   ...
# 129964    Alsace      NaN     Roger Voss            @vossroger
# 129965    Alsace      NaN     Roger Voss            @vossroger
# 129968    Alsace      NaN     Roger Voss            @vossroger
# 129969    Alsace      NaN     Roger Voss            @vossroger
# 129970    Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)        Frappato
# 7                   Trimbach 2012 Gewurztraminer (Alsace)  Gewürztraminer
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...      Pinot Gris
# 11                Leon Beyer 2012 Gewurztraminer (Alsace)  Gewürztraminer
# ...                                                   ...             ...
# 129964  Domaine Ehrhart 2013 Domaine Saint-Rémy Herren...  Gewürztraminer
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...      Pinot Gris
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                          winery
# 0                       Nicosia
# 6               Terre di Giurfo
# 7                      Trimbach
# 9            Jean-Baptiste Adam
# 11                   Leon Beyer
# ...                         ...
# 129964          Domaine Ehrhart
# 129965  Domaine Rieflé-Landmann
# 129968          Domaine Gresser
# 129969     Domaine Marcel Deiss
# 129970         Domaine Schoffit
#
# [41633 rows x 14 columns]

# %%
len(wine_reviews.loc[wine_reviews.country.isin(['Italy', 'France'])])
# Out:
# 41633

# %% [markdown]
# ### Új oszlop hozzáadása a Dataframe-hez
# Sokszor kalkulált mezőket kell hozzáfűzni a dataframe-hez.

# %% [markdown]
# Példa:
# <br>
# Egyes borok pontszámának az átlagtól való eltérése

# %%
wine_reviews['diff_from_avg_point'] = wine_reviews['points'] - wine_reviews['points'].mean()

# %% [markdown]
# Példa:
# <br>
# Flageljük meg 1-el azokat, amelyek átlagon aluli pontot kaptak és 0-val, ami átlag felettit

# %%
wine_reviews['underscored_flg'] = np.where(wine_reviews['points'] < wine_reviews['points'].mean(), 1, 0)

# %%
np.mean(wine_reviews['points'])
# Out:
# 88.44713820775404

# %%
wine_reviews[['points','underscored_flg']]
# Out:
#         points  underscored_flg
# 0           87                1
# 1           87                1
# 2           87                1
# 3           87                1
# 4           87                1
# ...        ...              ...
# 129966      90                0
# 129967      90                0
# 129968      90                0
# 129969      90                0
# 129970      90                0
#
# [129971 rows x 2 columns]

# %% [markdown]
# ### 2.1.4 Csoportosítások és aggregációk
# Az elemzés alapjául szolgáló üzleti adatokkal történő ismerkedéskor gyakran használt funkció a többször előforduló értékek vizsgálata, melyet a groupby függvénnyel kényelmesen meg lehet tenni.
# <br>
# Csoportosítani a groupby() függvénnyel lehet.

# %% [markdown]
# Példa:
# <br>
# Hány borkóstolást hajtottak végre a borkóstolók? (csökkenő sorrendbe)
# <br>
# Jól látszik a pédában, hogy a pandas függvények milyen jól hívhatók egy kifejezésben.

# %%
wine_reviews.groupby('taster_name').taster_name.count().sort_values(ascending=[False])
# Out:
# taster_name
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %% [markdown]
# Példa:
# <br>
# Top3 borkóstoló, akinek a legtöbb értékelése van

# %%
wine_reviews.groupby('taster_name').taster_name.count().sort_values(ascending=[False]).head(3)
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
# Kerin O’Keefe        10776
# Name: taster_name, dtype: int64

# %% [markdown]
# Példa:
# <br>
# Melyik a legolcsóbb bor egyes pontoknál?

# %%
wine_reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %% [markdown]
# A groupby() és az agg() függvény segítségével több leíró statisztikát is futtathatunk
# <br>
# Példa:
# <br>
# Országonként hány bort véleményeztek és országonként a bor árainak mik a szélsőértékei?

# %%
wine_reviews.groupby(['country']).price.agg([len, min, max]).head(10)
# Out:
#                            len   min     max
# country
# Argentina               3800.0   4.0   230.0
# Armenia                    2.0  14.0    15.0
# Australia               2329.0   5.0   850.0
# Austria                 3345.0   7.0  1100.0
# Bosnia and Herzegovina     2.0  12.0    13.0
# Brazil                    52.0  10.0    60.0
# Bulgaria                 141.0   8.0   100.0
# Canada                   257.0  12.0   120.0
# Chile                   4472.0   5.0   400.0
# China                      1.0  18.0    18.0

# %% [markdown]
# ### 2.1.5 Hiányzó értékek keresése

# %% [markdown]
# Hiányzó értékek száma oszloponnként:

# %%
wine_reviews.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# diff_from_avg_point          0
# underscored_flg              0
# dtype: int64

# %% [markdown]
# ### 2.1.6 Hiányzó értékek kezelése

# %% [markdown]
# Numerikus oszlopokban középértékkel (módusz, medián, átlag) vagy a leggyakrabban előforduló értékekkel (ordinális változók) helyettesíthetjük a hiányzó értékeket:

# %%
wine_reviews.price.fillna((wine_reviews['price'].mean()), inplace=True)

# %% [markdown]
# Kategorikus változóknál a leggyakrabban előforduló értékekkel helyettesíthetjük a hiányzó értékeket:

# %%
wine_reviews.country.fillna(wine_reviews.country.mode().iloc[0], inplace = True) # mode(): legsűrűbben előforduló értékeket adja vissza
wine_reviews.province.fillna(wine_reviews.province.mode().iloc[0], inplace = True)

# %%
wine_reviews['taster_name'] = wine_reviews.groupby(['country', 'province'])['taster_name'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else "Empty"))

# %%
wine_reviews.isnull().sum()[wine_reviews.isnull().sum() > 0]
# Out:
# designation              37465
# region_1                 21247
# region_2                 79460
# taster_twitter_handle    31213
# variety                      1
# dtype: int64
